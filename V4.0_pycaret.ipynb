# %%
from utils import *

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

from sklearn.preprocessing import LabelEncoder
from pycaret.classification import *

# %%
df4 = pd.read_pickle("./pickles_temp/V3_1.pkl")

# %%
df4['date_recorded'] = pd.to_datetime(df4['date_recorded'])

df4['year_recorded'] = df4['date_recorded'].dt.year

df4.head
# Out:
# <bound method NDFrame.head of           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman      1390.0
# 1       8776         0.0    2013-03-06          Grumeti      1399.0
# 2      34310        25.0    2013-02-25     Lottery Club       686.0
# 3      67743         0.0    2013-01-28           Unicef       263.0
# 4      19728         0.0    2011-07-13      Action In A         NaN
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi      1210.0
# 59396  27263      4700.0    2011-05-07      Cefa-njombe      1212.0
# 59397  37057         0.0    2011-04-11              NaN         NaN
# 59398  31282         0.0    2011-03-08            Malec         NaN
# 59399  26348         0.0    2011-03-23       World Bank       191.0
#
#           installer  longitude   latitude              wpt_name  num_private  \
# ...

# %%
df4.year_recorded.value_counts()
# No parece que aporte mucha información pero de momento lo vamos a dejar
# Out:
# year_recorded
# 2011    28674
# 2013    24271
# 2012     6424
# 2004       30
# 2002        1
# Name: count, dtype: int64

# %%
# pero vamos a eliminar la fecha original
del df4['date_recorded']

# %%
# Probamos a darle valor numerico a las variables categoricas
variables_object = df4.select_dtypes(include=['object'])

label_encoder = LabelEncoder()

for x in variables_object:
    df4[x] = label_encoder.fit_transform(df4[x])

# %%
missing_values_summary(df4)
# Out:
#                        Valores Nulos  % de Valores Nulos
# id                                 0                 0.0
# amount_tsh                         0                 0.0
# funder                             0                 0.0
# gps_height                     21934                36.9
# installer                          0                 0.0
# longitude                       1812                 3.1
# latitude                        1812                 3.1
# wpt_name                           0                 0.0
# num_private                        0                 0.0
# basin                              0                 0.0
# subvillage                         0                 0.0
# region                             0                 0.0
# region_code                        0                 0.0
# district_code                      0                 0.0
# lga                                0                 0.0
# ...

# %%
import feature_engine.imputation as fe_imp

df4_1 = df4.copy()
# Suponiendo que df4 es tu DataFrame original

# Creamos una instancia del imputador aleatorio
imputer_rand = fe_imp.RandomSampleImputer(random_state=42)  
#imputer_knn = skl_imp.KNNImputer(n_neighbors=3)

# Ajustamos el imputador a los datos
imputer_rand.fit(df4_1)
#imputer_knn.fit(df4_1)
# Imputamos los valores faltantes aleatoriamente en el DataFrame
df4_1_imputed = imputer_knn.transform(df4_1) ## para imputer_rand
#df4_1_imputed = imputer_knn.transform(df4_1)

# %%
df4_1_imputed
# Out:
# array([[6.9572e+04, 6.0000e+03, 1.3670e+03, ..., 1.0000e+00, 0.0000e+00,
#         2.0110e+03],
#        [8.7760e+03, 0.0000e+00, 4.6800e+02, ..., 1.0000e+00, 0.0000e+00,
#         2.0130e+03],
#        [3.4310e+04, 2.5000e+01, 8.2400e+02, ..., 2.0000e+00, 0.0000e+00,
#         2.0130e+03],
#        ...,
#        [3.7057e+04, 0.0000e+00, 1.8950e+03, ..., 4.0000e+00, 0.0000e+00,
#         2.0110e+03],
#        [3.1282e+04, 0.0000e+00, 8.8300e+02, ..., 4.0000e+00, 0.0000e+00,
#         2.0110e+03],
#        [2.6348e+04, 0.0000e+00, 1.8630e+03, ..., 4.0000e+00, 0.0000e+00,
#         2.0110e+03]])

# %%
model_setup = setup(data=df4_1_imputed, 
                    target = 'status_group', 
                    session_id=1, 
                    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model_setup = setup(data=df4_1_imputed,
#       2                     target = 'status_group',
#       3                     session_id=1,
#       4                     )
#
# ...

# %%
best_model = compare_models()

# %% [markdown]
# rf	Random Forest Classifier
#
# Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC	TT (Sec)
#
# 0.8028	0.9024	0.8028	0.7976	0.7929	0.6262	0.6329	2.1650
