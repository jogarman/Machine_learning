# %%
from V5_tratamiento_no_funciona import tratamiento
from utils import *

import pandas as pd
import numpy as np

# %%
df_test_set=pd.read_csv('./test set values.csv', sep=',')
df_test_set
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 0      50785         0.0    2013-02-04                    Dmdd        1996
# 1      51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2      17168         0.0    2013-02-01                     NaN        1567
# 3      45559         0.0    2013-01-22              Finn Water         267
# 4      49871       500.0    2013-03-27                  Bruder        1260
# ...      ...         ...           ...                     ...         ...
# 14845  39307         0.0    2011-02-24                  Danida          34
# 14846  18990      1000.0    2011-03-21                    Hiap           0
# 14847  28749         0.0    2013-03-04                     NaN        1476
# 14848  33492         0.0    2013-02-18                 Germany         998
# 14849  68707         0.0    2013-02-13  Government Of Tanzania         481
#
# ...

# %%
# Quiero corroborar que no hay errores al importar la bbdd de test set (Los habrá)

df_test_set_tratado = tratamiento(df_test_set)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9590 entries, 0 to 14849
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9590 non-null   int64
#  1   wpt_name           9590 non-null   object
#  2   subvillage         9590 non-null   object
#  3   ward               9590 non-null   object
#  4   construction_year  9590 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 449.5+ KB
# Para obtener construction_year
# <style type="text/css">
# #T_80f0b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_80f0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80f0b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_80f0b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# Interesante error. Parece que hay etiquetas que el modelo no ha visto antes. No llego a comprender exactamente por qué

# Lo importante es que he aprendido que NO se deben utilizar algoritmos predictivos como random forest para rellenar missings.
# Me pareció una idea original y precisa y pensé que debía usarse puesto que tenía una correlación con la variable objetivo bastante alta y 
#   un 40% de missings. 

# Muy a mi pesar, voy a imputar aleatoriamente, ya le he dedicado bastante tiempo
