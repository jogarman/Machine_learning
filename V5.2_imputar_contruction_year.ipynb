# %%
from utils import *

import pandas as pd
import numpy as np

from feature_engine.imputation import RandomSampleImputer

# %%
df6 = pd.read_pickle("./pickles_temp/V4_4.pkl") 
missing_values_summary(df6)
# Out:
#                        Valores Nulos  % de Valores Nulos
# id                                 0                 0.0
# amount_tsh                         0                 0.0
# funder                             0                 0.0
# gps_height                         0                 0.0
# installer                          0                 0.0
# longitude                          0                 0.0
# latitude                           0                 0.0
# wpt_name                           0                 0.0
# num_private                        0                 0.0
# basin                              0                 0.0
# subvillage                         0                 0.0
# region                             0                 0.0
# region_code                        0                 0.0
# district_code                      0                 0.0
# lga                                0                 0.0
# ...

# %%
df6_imputed_data = df6.copy()

imputer = RandomSampleImputer()
df6_imputed_data['construction_year'] = imputer.fit_transform(df6[['construction_year']])
missing_values_summary(df6_imputed_data)
# Out:
#                        Valores Nulos  % de Valores Nulos
# id                                 0                 0.0
# amount_tsh                         0                 0.0
# funder                             0                 0.0
# gps_height                         0                 0.0
# installer                          0                 0.0
# longitude                          0                 0.0
# latitude                           0                 0.0
# wpt_name                           0                 0.0
# num_private                        0                 0.0
# basin                              0                 0.0
# subvillage                         0                 0.0
# region                             0                 0.0
# region_code                        0                 0.0
# district_code                      0                 0.0
# lga                                0                 0.0
# ...

# %%
df6_imputed_data.to_pickle("./pickles_temp/V5_2_base.pkl")

# Ya tenemos la base con la que vamos a trabajar
